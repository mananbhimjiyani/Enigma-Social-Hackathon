# %% [markdown]
# ## Importing libraries and getting data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from scipy import stats

# %%
data=pd.read_csv(r"C:\Users\sairam\Desktop\data science\datasets\breast-cancer.csv")
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 0  ...         25.38          17.33           184.60      2019.0
# 1  ...         24.99          23.41           158.80      1956.0
# 2  ...         23.57          25.53           152.50      1709.0
# 3  ...         14.91          26.50            98.87       567.7
# 4  ...         22.54          16.67           152.20      1575.0
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    symmetry_worst  fractal_dimension_worst
# 0          0.4601                  0.11890
# 1          0.2750                  0.08902
# 2          0.3613                  0.08758
# 3          0.6638                  0.17300
# 4          0.2364                  0.07678
#
# [5 rows x 32 columns]

# %% [markdown]
# The Id column is not needed, hence we can drop it.

# %% [markdown]
# ## Data cleaning and pre-processing

# %%
data=data.drop(['id'],axis=1)
data.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0         0.2419  ...         25.38          17.33           184.60
# 1         0.1812  ...         24.99          23.41           158.80
# 2         0.2069  ...         23.57          25.53           152.50
# 3         0.2597  ...         14.91          26.50            98.87
# 4         0.1809  ...         22.54          16.67           152.20
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 31 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   diagnosis                569 non-null    object
#  1   radius_mean              569 non-null    float64
#  2   texture_mean             569 non-null    float64
#  3   perimeter_mean           569 non-null    float64
#  4   area_mean                569 non-null    float64
#  5   smoothness_mean          569 non-null    float64
#  6   compactness_mean         569 non-null    float64
#  7   concavity_mean           569 non-null    float64
#  8   concave points_mean      569 non-null    float64
#  9   symmetry_mean            569 non-null    float64
#  10  fractal_dimension_mean   569 non-null    float64
#  11  radius_se                569 non-null    float64
#  12  texture_se               569 non-null    float64
#  13  perimeter_se             569 non-null    float64
#  14  area_se                  569 non-null    float64
#  15  smoothness_se            569 non-null    float64
#  16  compactness_se           569 non-null    float64
#  17  concavity_se             569 non-null    float64
#  18  concave points_se        569 non-null    float64
#  19  symmetry_se              569 non-null    float64
#  20  fractal_dimension_se     569 non-null    float64
#  21  radius_worst             569 non-null    float64
#  22  texture_worst            569 non-null    float64
#  23  perimeter_worst          569 non-null    float64
#  24  area_worst               569 non-null    float64
#  25  smoothness_worst         569 non-null    float64
#  26  compactness_worst        569 non-null    float64
#  27  concavity_worst          569 non-null    float64
#  28  concave points_worst     569 non-null    float64
#  29  symmetry_worst           569 non-null    float64
#  30  fractal_dimension_worst  569 non-null    float64
# dtypes: float64(30), object(1)
# memory usage: 137.9+ KB

# %% [markdown]
# The data does not contain any null values. hence we need to worry about them. The next we can check for duplicate values.

# %%
data.duplicated()
data=data.drop_duplicates()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   diagnosis                569 non-null    object
#  1   radius_mean              569 non-null    float64
#  2   texture_mean             569 non-null    float64
#  3   perimeter_mean           569 non-null    float64
#  4   area_mean                569 non-null    float64
#  5   smoothness_mean          569 non-null    float64
#  6   compactness_mean         569 non-null    float64
#  7   concavity_mean           569 non-null    float64
#  8   concave points_mean      569 non-null    float64
#  9   symmetry_mean            569 non-null    float64
#  10  fractal_dimension_mean   569 non-null    float64
#  11  radius_se                569 non-null    float64
#  12  texture_se               569 non-null    float64
#  13  perimeter_se             569 non-null    float64
#  14  area_se                  569 non-null    float64
#  15  smoothness_se            569 non-null    float64
#  16  compactness_se           569 non-null    float64
#  17  concavity_se             569 non-null    float64
#  18  concave points_se        569 non-null    float64
#  19  symmetry_se              569 non-null    float64
#  20  fractal_dimension_se     569 non-null    float64
#  21  radius_worst             569 non-null    float64
#  22  texture_worst            569 non-null    float64
#  23  perimeter_worst          569 non-null    float64
#  24  area_worst               569 non-null    float64
#  25  smoothness_worst         569 non-null    float64
#  26  compactness_worst        569 non-null    float64
#  27  concavity_worst          569 non-null    float64
#  28  concave points_worst     569 non-null    float64
#  29  symmetry_worst           569 non-null    float64
#  30  fractal_dimension_worst  569 non-null    float64
# dtypes: float64(30), object(1)
# memory usage: 137.9+ KB

# %% [markdown]
# The data doesn't contain any duplicate values. Hence we need to worry about them. The next step is to convert the character values present in the diagnosis column to integers so that they can be used as target varaibles for classification.

# %%
data['diagnosis'].unique()
# Out:
# array(['M', 'B'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
encode=LabelEncoder()
data['diagnosis']=encode.fit_transform(data['diagnosis'])
data['diagnosis'].unique()
data.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1        17.99         10.38          122.80     1001.0
# 1          1        20.57         17.77          132.90     1326.0
# 2          1        19.69         21.25          130.00     1203.0
# 3          1        11.42         20.38           77.58      386.1
# 4          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0         0.2419  ...         25.38          17.33           184.60
# 1         0.1812  ...         24.99          23.41           158.80
# 2         0.2069  ...         23.57          25.53           152.50
# 3         0.2597  ...         14.91          26.50            98.87
# 4         0.1809  ...         22.54          16.67           152.20
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 31 columns]

# %% [markdown]
# The next step us feature scaling. I thought of bringing all the values to the same scale, hence I standardised the data.

# %%
data1=data.copy()
data1=data1.drop(['diagnosis'],axis=1)
#lis=['Glucose','BloodPressure','SkinThickness','Insulin','BMI','DiabetesPedigreeFunction','Age','Pregnancies']
for column in data1.columns:
    data1[column] = (data1[column] - data1[column].min()) / (data1[column].max() - data1[column].min()) 
data1.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0     0.521037      0.022658        0.545989   0.363733         0.593753
# 1     0.643144      0.272574        0.615783   0.501591         0.289880
# 2     0.601496      0.390260        0.595743   0.449417         0.514309
# 3     0.210090      0.360839        0.233501   0.102906         0.811321
# 4     0.629893      0.156578        0.630986   0.489290         0.430351
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0          0.792037        0.703140             0.731113       0.686364
# 1          0.181768        0.203608             0.348757       0.379798
# 2          0.431017        0.462512             0.635686       0.509596
# 3          0.811361        0.565604             0.522863       0.776263
# 4          0.347893        0.463918             0.518390       0.378283
#
#    fractal_dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0                0.605518  ...      0.620776       0.141525         0.668310
# 1                0.141323  ...      0.606901       0.303571         0.539818
# 2                0.211247  ...      0.556386       0.360075         0.508442
# 3                1.000000  ...      0.248310       0.385928         0.241347
# 4                0.186816  ...      0.519744       0.123934         0.506948
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0    0.450698          0.601136           0.619292         0.568610
# 1    0.435214          0.347553           0.154563         0.192971
# 2    0.374508          0.483590           0.385375         0.359744
# 3    0.094008          0.915472           0.814012         0.548642
# 4    0.341575          0.437364           0.172415         0.319489
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0              0.912027        0.598462                 0.418864
# 1              0.639175        0.233590                 0.222878
# 2              0.835052        0.403706                 0.213433
# 3              0.884880        1.000000                 0.773711
# 4              0.558419        0.157500                 0.142595
#
# [5 rows x 30 columns]

# %% [markdown]
# I thought of working with the mean data alone, since i wanted to get data from the user. The data he enters would more or less be same to that of mean compared to se and worst case.

# %%
x=data1.drop(['fractal_dimension_worst','symmetry_worst','concave points_worst','concavity_worst','compactness_worst','smoothness_worst','area_worst','perimeter_worst','texture_worst','radius_worst','fractal_dimension_se','symmetry_se','concave points_se','concavity_se','compactness_se','smoothness_se','area_se','perimeter_se','texture_se','radius_se'],axis=1)
x.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0     0.521037      0.022658        0.545989   0.363733         0.593753
# 1     0.643144      0.272574        0.615783   0.501591         0.289880
# 2     0.601496      0.390260        0.595743   0.449417         0.514309
# 3     0.210090      0.360839        0.233501   0.102906         0.811321
# 4     0.629893      0.156578        0.630986   0.489290         0.430351
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0          0.792037        0.703140             0.731113       0.686364
# 1          0.181768        0.203608             0.348757       0.379798
# 2          0.431017        0.462512             0.635686       0.509596
# 3          0.811361        0.565604             0.522863       0.776263
# 4          0.347893        0.463918             0.518390       0.378283
#
#    fractal_dimension_mean
# 0                0.605518
# 1                0.141323
# 2                0.211247
# 3                1.000000
# 4                0.186816

# %%
y=data['diagnosis']
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest= train_test_split(x,y,test_size=0.1,stratify=y)
print(xtrain.shape)
print(xtest.shape)
print(ytrain.shape)
print(ytest.shape)
# Out:
# (512, 10)
# (57, 10)
# (512,)
# (57,)

# %%
from sklearn.svm import SVC
svm_model= SVC(kernel='rbf',gamma=8)
svm_model.fit(xtrain,ytrain)
# Out:
# SVC(gamma=8)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
predictions= svm_model.predict(xtrain)
percentage=svm_model.score(xtrain,ytrain)
res=confusion_matrix(ytrain,predictions)
print("Training confusion matrix")
print(res)
predictions= svm_model.predict(xtest)
percentage=svm_model.score(xtest,ytest)
res=confusion_matrix(ytest,predictions)
print("validation confusion matrix")
print(res)
print(classification_report(ytest, predictions))
# check the accuracy on the training set
print('training accuracy = '+str(svm_model.score(xtrain, ytrain)*100))
print('testing accuracy = '+str(svm_model.score(xtest, ytest)*100))
# Out:
# Training confusion matrix
# [[317   4]
#  [ 11 180]]
# validation confusion matrix
# [[34  2]
#  [ 1 20]]
#               precision    recall  f1-score   support
#
#            0       0.97      0.94      0.96        36
#            1       0.91      0.95      0.93        21
#
#     accuracy                           0.95        57
#    macro avg       0.94      0.95      0.94        57
# weighted avg       0.95      0.95      0.95        57
#
# training accuracy = 97.0703125
# testing accuracy = 94.73684210526315

# %% [markdown]
# ### The SVM produced 94% testing accuracy.
#
# ## ANN

# %%
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout
dl_model = Sequential() 

dl_model.add(Dense(256,  activation = 'relu' ,input_shape=([10]))) #input layer
dl_model.add(Dense(256,  activation = 'relu'))
dl_model.add(Dense(1,activation = 'sigmoid'))
dl_model.summary()
dl_model.compile(optimizer = 'adam' , loss = 'binary_crossentropy' ,metrics = ['accuracy','Precision','Recall','AUC'])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 256)               2816
#
#  dense_1 (Dense)             (None, 256)               65792
#
#  dense_2 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 68,865
# Trainable params: 68,865
# Non-trainable params: 0
# _________________________________________________________________

# %%
print(tf.keras.__version__)
# Out:
# 2.9.0

# %%
num_epochs = 20
history = dl_model.fit(xtrain ,
                    ytrain ,
                    epochs= num_epochs ,
                    steps_per_epoch=70,
                    validation_data=(xtest ,ytest))
# Out:
# Epoch 1/20
# 70/70 [==============================] - 3s 17ms/step - loss: 0.4513 - accuracy: 0.8339 - precision: 0.8851 - recall: 0.6329 - auc: 0.8868 - val_loss: 0.2463 - val_accuracy: 0.9298 - val_precision: 0.8400 - val_recall: 1.0000 - val_auc: 0.9854
# Epoch 2/20
# 70/70 [==============================] - 0s 4ms/step - loss: 0.2439 - accuracy: 0.9089 - precision: 0.9010 - recall: 0.8545 - auc: 0.9600 - val_loss: 0.2324 - val_accuracy: 0.8947 - val_precision: 0.7778 - val_recall: 1.0000 - val_auc: 0.9881
# Epoch 3/20
# 70/70 [==============================] - 0s 3ms/step - loss: 0.1986 - accuracy: 0.9179 - precision: 0.9118 - recall: 0.8692 - auc: 0.9728 - val_loss: 0.1690 - val_accuracy: 0.9123 - val_precision: 0.8333 - val_recall: 0.9524 - val_auc: 0.9881
# Epoch 4/20
# 70/70 [==============================] - 0s 4ms/step - loss: 0.1671 - accuracy: 0.9321 - precision: 0.9179 - recall: 0.8905 - auc: 0.9788 - val_loss: 0.1460 - val_accuracy: 0.9474 - val_precision: 0.9500 - val_recall: 0.9048 - val_auc: 0.9854
# Epoch 5/20
# 70/70 [==============================] - 0s 4ms/step - loss: 0.1545 - accuracy: 0.9304 - precision: 0.9333 - recall: 0.8750 - auc: 0.9851 - val_loss: 0.2557 - val_accuracy: 0.8772 - val_precision: 0.7500 - val_recall: 1.0000 - val_auc: 0.9848
# Epoch 6/20
# 70/70 [==============================] - 0s 4ms/step - loss: 0.1386 - accuracy: 0.9393 - precision: 0.9279 - recall: 0.9104 - auc: 0.9871 - val_loss: 0.1749 - val_accuracy: 0.9298 - val_precision: 0.8696 - val_recall: 0.9524 - val_auc: 0.9854
# Epoch 7/20
# 70/70 [==============================] - 0s 5ms/step - loss: 0.1863 - accuracy: 0.9232 - precision: 0.9119 - recall: 0.8713 - auc: 0.9752 - val_loss: 0.1704 - val_accuracy: 0.9298 - val_precision: 0.8696 - val_recall: 0.9524 - val_auc: 0.9861
# Epoch 8/20
# 70/70 [==============================] - 0s 5ms/step - loss: 0.1240 - accuracy: 0.9518 - precision: 0.9592 - recall: 0.9082 - auc: 0.9895 - val_loss: 0.1921 - val_accuracy: 0.9123 - val_precision: 0.8333 - val_recall: 0.9524 - val_auc: 0.9861
# Epoch 9/20
# 70/70 [==============================] - 0s 5ms/step - loss: 0.1282 - accuracy: 0.9429 - precision: 0.9333 - recall: 0.9159 - auc: 0.9887 - val_loss: 0.1450 - val_accuracy: 0.9298 - val_precision: 0.9048 - val_recall: 0.9048 - val_auc: 0.9854
# Epoch 10/20
# 70/70 [==============================] - 0s 5ms/step - loss: 0.1273 - accuracy: 0.9429 - precision: 0.9444 - recall: 0.8990 - auc: 0.9875 - val_loss: 0.1341 - val_accuracy: 0.9649 - val_precision: 0.9524 - val_recall: 0.9524 - val_auc: 0.9881
# Epoch 11/20
# 70/70 [==============================] - 0s 4ms/step - loss: 0.1338 - accuracy: 0.9411 - precision: 0.9289 - recall: 0.9159 - auc: 0.9877 - val_loss: 0.1299 - val_accuracy: 0.9474 - val_precision: 0.9091 - val_recall: 0.9524 - val_auc: 0.9881
# Epoch 12/20
# 70/70 [==============================] - 0s 4ms/step - loss: 0.1209 - accuracy: 0.9500 - precision: 0.9356 - recall: 0.9265 - auc: 0.9899 - val_loss: 0.1638 - val_accuracy: 0.9298 - val_precision: 0.8696 - val_recall: 0.9524 - val_auc: 0.9881
# Epoch 13/20
# 70/70 [==============================] - 0s 4ms/step - loss: 0.1125 - accuracy: 0.9500 - precision: 0.9515 - recall: 0.9159 - auc: 0.9916 - val_loss: 0.3554 - val_accuracy: 0.8772 - val_precision: 0.7500 - val_recall: 1.0000 - val_auc: 0.9894
# Epoch 14/20
# 70/70 [==============================] - 0s 3ms/step - loss: 0.1290 - accuracy: 0.9375 - precision: 0.9112 - recall: 0.9242 - auc: 0.9888 - val_loss: 0.2054 - val_accuracy: 0.9123 - val_precision: 0.8333 - val_recall: 0.9524 - val_auc: 0.9901
# Epoch 15/20
# 70/70 [==============================] - 0s 3ms/step - loss: 0.1148 - accuracy: 0.9482 - precision: 0.9403 - recall: 0.9175 - auc: 0.9891 - val_loss: 0.2212 - val_accuracy: 0.8947 - val_precision: 0.8000 - val_recall: 0.9524 - val_auc: 0.9894
# Epoch 16/20
# 70/70 [==============================] - 0s 3ms/step - loss: 0.1146 - accuracy: 0.9589 - precision: 0.9569 - recall: 0.9346 - auc: 0.9897 - val_loss: 0.1798 - val_accuracy: 0.9298 - val_precision: 0.8696 - val_recall: 0.9524 - val_auc: 0.9894
# Epoch 17/20
# 70/70 [==============================] - 0s 3ms/step - loss: 0.1159 - accuracy: 0.9554 - precision: 0.9479 - recall: 0.9239 - auc: 0.9902 - val_loss: 0.1640 - val_accuracy: 0.9298 - val_precision: 0.8696 - val_recall: 0.9524 - val_auc: 0.9894
# Epoch 18/20
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0928 - accuracy: 0.9625 - precision: 0.9612 - recall: 0.9384 - auc: 0.9937 - val_loss: 0.1641 - val_accuracy: 0.9298 - val_precision: 0.8696 - val_recall: 0.9524 - val_auc: 0.9894
# Epoch 19/20
# 16/70 [=====>........................] - ETA: 0s - loss: 0.1081 - accuracy: 0.9531 - precision: 0.9434 - recall: 0.9434 - auc: 0.9926WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 1400 batches). You may need to use the repeat() function when building your dataset.
# 70/70 [==============================] - 2s 23ms/step - loss: 0.1185 - accuracy: 0.9500 - precision: 0.9365 - recall: 0.9365 - auc: 0.9899 - val_loss: 0.1433 - val_accuracy: 0.9298 - val_precision: 0.8696 - val_recall: 0.9524 - val_auc: 0.9888

# %%
dl_model.evaluate(xtest,ytest)
# Out:
# 2/2 [==============================] - 0s 0s/step - loss: 0.1727 - accuracy: 0.9298 - precision: 0.9474 - recall: 0.8571 - auc: 0.9755
# [0.17271898686885834,
#  0.9298245906829834,
#  0.9473684430122375,
#  0.8571428656578064,
#  0.975529134273529]

# %%
dl_model.save('breast_cancer_radiological_data-ANN.h5')

# %% [markdown]
# ## Sample prediction

# %%
x1=float(input())
x2=float(input())
x3=float(input())
x4=float(input())
x5=float(input())
x6=float(input())
x7=float(input())
x8=float(input())
x9=float(input())
x10=float(input())
inp=[[x1,x2,x3,x4,x5,x6,x7,x8,x9,x10]]
for x in inp:
    x=x-np.max(x)/(np.max(x)-np.min(x))
out=dl_model.predict(inp)
a=out[0]
print(a)
if a>0.5:
    print('Malignant')
else:
    print('Benign')
# Out:
# 0
# 0
# 0
# 0
# 1
# 2
# 0
# 0
# 3
# 4
# 1/1 [==============================] - 0s 32ms/step
# [8.706901e-15]
# Benign
